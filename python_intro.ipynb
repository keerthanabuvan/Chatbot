# %% [markdown]
# #PYTHON

# %% [markdown]
# # Introduction

# %% [markdown]
# *   Python is a general-purpose interpreted,
# *   interactive,
# * object-oriented, and
# * high-level programming language.

# %% [markdown]
# ---

# %% [markdown]
# **Why Python**
#
# * Python is a Beginner's Language
# * Open source
# * Wide Range of Applications
# * Library

# %% [markdown]
# ![python-applications.png](data:image/png;base64,...)

# %%
print("s")
# Out:
# s

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
2+3

# %% [markdown]
# Assigning values

# %%
i = 100          # An integer 
f = 1000.0       # A floating point
s = "John"       # A string

print(i)
print(f)
print(s)
# Out:
# 100
# 1000.0
# John

# %%
print(type(i))  
print(type(f))  
print(type(s))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
print(type(True))  
print(type(False))
# Out:
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# Multiple Assignment

# %%
a = b = c = 1
print(a,b,c)
# Out:
# 1 1 1

# %%
a,b,c = 1,2,"john"
print(a,b,c)
# Out:
# 1 2 john

# %% [markdown]
# # Datatypes

# %% [markdown]
# Python has five standard data types
#
# 1. Number
# 2. String
# 3. List
# 4. Tuple
# 5. Dictionary

# %% [markdown]
# Number

# %%
var1 = 1
print(var1)
type(var1)
# Out:
# 1
# int

# %%
var2 = 40.5  
print(var2)
type(var2)
# Out:
# 40.5
# float

# %%
var3 = 1+3j  
print(var3)
type(var3)
# Out:
# (1+3j)
# complex

# %% [markdown]
# String

# %%
strng = 'Hello World'
print(strng)
# Out:
# Hello World

# %%
print(strng[10])
# Out:
# d

# %%
print(strng[0])
# Out:
# H

# %%
print(strng[2:5])
# Out:
# llo

# %%
print(strng[6:7])
# Out:
# W

# %%
print(strng[2:])
# Out:
# llo World

# %%
print(strng[-1])
# Out:
# d

# %%
print(strng * 2)
# Out:
# Hello WorldHello World

# %%
print(strng + "TEST")
# Out:
# Hello WorldTEST

# %%
print(strng[::-1])
# Out:
# dlroW olleH

# %%
print(strng[13])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-27caedda2baf> in <module>()
# ----> 1 print(strng[13])
#
# IndexError: string index out of range

# %% [markdown]
# A list contains items separated by commas and enclosed within square brackets []

# %%
lst = [ 'a', 786 , 2.23, 'john', 70.2 ]
print(lst)
print(type(lst))
# Out:
# ['a', 786, 2.23, 'john', 70.2]
# <class 'list'>

# %%
print(lst[0])
# Out:
# a

# %%
print(lst[1:3])
# Out:
# [786, 2.23]

# %%
lst[2] = 1000   
print(lst)
# Out:
# ['a', 786, 1000, 'john', 70.2]

# %%
lst.append(3)
print(lst)
# Out:
# ['a', 786, 1000, 'john', 70.2, 3]

# %%
lst.insert(5,4)
print(lst)
# Out:
# ['a', 786, 1000, 'john', 70.2, 4, 3]

# %%
lst.remove(786)
print(lst)
# Out:
# ['a', 1000, 'john', 70.2, 4, 3]

# %% [markdown]
# A tuple consists of a number of values separated by commas, enclosed within parentheses.

# %%
tple = ( 'abcd', 786 , 2.23, 'john', 70.2  )
print(tple)
# Out:
# ('abcd', 786, 2.23, 'john', 70.2)

# %%
tple[2] = 1000    # Invalid syntax with tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-e0d9d1d3b50c> in <module>()
# ----> 1 tple[2] = 1000    # Invalid syntax with tuple
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Python's dictionaries are kind of hash table type, stored in key-value pairs.
#
# Dictionaries are enclosed by curly braces { }

# %%
dict1 = {'name': 'john','code':6734, 'dept': 'sales'}
print(dict1)
print(type(dict1))
# Out:
# {'name': 'john', 'code': 6734, 'dept': 'sales'}
# <class 'dict'>

# %%
dict1['one'] = "This is one"
dict1[2]     = "This is two"

# %%
print(dict1)
# Out:
# {'name': 'john', 'code': 6734, 'dept': 'sales', 'one': 'This is one', 2: 'This is two'}

# %%
dict1.keys()
# Out:
# dict_keys(['name', 'code', 'dept', 'one', 2])

# %%
dict1.values()
# Out:
# dict_values(['john', 6734, 'sales', 'This is one', 'This is two'])

# %% [markdown]
# Set is the unordered collection of the data type, it is mutable and has unique elements.

# %%
st={1,2,3,4,5}
print(st)
print(type(st))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
st={1,2,1,3,4}
print(st)
print(type(st))
# Out:
# {1, 2, 3, 4}
# <class 'set'>

# %%
st.add(10)  
print(st)
# Out:
# {1, 2, 3, 4, 10}

# %%
st.remove(2)  
print(st)
# Out:
# {1, 3, 4, 10}

# %% [markdown]
# # Decision making and looping statements

# %% [markdown]
# If statement

# %%
num = int(input("enter the number?"))  
if(num%2 == 0):  
    print("Number is even") 
else:
  print("Number is odd")
# Out:
# enter the number?14
# Number is even

# %%
marks = int(input("Enter the marks? "))  
if(marks > 85 and marks <= 100):  
   print("Congrats ! you scored grade A ...")  
elif(marks > 60 and marks <= 85):  
   print("You scored grade B + ...")  
elif(marks > 40 and marks <= 60):  
   print("You scored grade B ...")  
elif(marks > 30 and marks <= 40):  
   print("You scored grade C ...")  
else:  
   print("Sorry you are fail ?")
# Out:
# Enter the marks? 30
# Sorry you are fail ?

# %% [markdown]
# For loop

# %%
str = "Python"  
for i in str:  
    print(i)
# Out:
# P
# y
# t
# h
# o
# n

# %%
for i in range(10,2,-1):  
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3

# %% [markdown]
# While loop
#
# The while loop will iterate until condition becomes false.

# %%
i=1    
while(i<=10):    
    print(i)

# %% [markdown]
# #Functions

# %% [markdown]
# There are mainly two types of functions.
#
# User-define functions - The user-defined functions are those define by the user to perform the specific task.
#
# Built-in functions - The built-in functions are those functions that are pre-defined in Python

# %%
import math
math.pi

# %%
#function definition
def func():    
    print("hello world") 

# function calling  
func()

# %%
def sum():  
    a = 10  
    b = 20  
    c = a+b  
    return c    
print("The sum is:",sum())

# %% [markdown]
# Arguments in function

# %%
def func (name):    
    print("Hi ",name)      
func("keerthu")

# %% [markdown]
# Default Arguments

# %%
def printme(name,age=22):    
    print("My name is",name,"and age is",age)    
printme(name = "naina")
